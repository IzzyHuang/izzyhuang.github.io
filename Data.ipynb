# %% [markdown]
# # TODO: Figure out a Less Carbed breakfast

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings("ignore")

# %%
### Shoulder ###
DumbbellShoulderPress = ["Shoulder", "Front Deltoid", "Dumbbell Shoulder Press", "3", "30", "10", "Stand or sit with a dumbbell in each hand at shoulder height, palms facing forward, and press the weights vertically overhead until your arms are fully extended, then lower back to the starting position."]
DumbbellFrontRaise = ["Shoulder", "Front Deltoid", "Dumbbell Front Raise", "3", "10", "10", "Hold a dumbbell in each hand in front of your thighs and raise them forward to shoulder height, then lower back down with control."]
ArnoldPress = ["Shoulder", "Front Deltoid", "Arnold Press", "3", "30", "8", "Start seated or standing with dumbbells held in front of your shoulders, palms facing you; as you press the dumbbells overhead, rotate your hands so your palms face forward at the top, then reverse the motion when lowering back to start."]
LeverShoulderPress = ["Shoulder", "Front Deltoid", "Lever Shoulder Press", "3", "70", "8", "Sit on the lever press machine with back flat against the pad, grip the handles at shoulder height, and press upwards until arms are extended, then lower back down."]
DumbbellLateralRaise = ["Shoulder", "Lateral Deltoid", "Dumbbell Lateral Raise", "3", "10", "10", "Stand with feet shoulder-width apart, dumbbells at your sides, palms facing in; lift the dumbbells out to your sides with a slight bend in the elbows, raising them to shoulder height, then slowly lower back down."]
CableLateralRaise = ["Shoulder", "Lateral Deltoid", "Cable Lateral Raise", "3", "10", "10", "Stand next to a cable machine, grab the low pulley handle with the hand farthest from it, keep your body straight, and lift your arm out to the side to shoulder height, then slowly lower back down."]
CableRearDeltFly = ["Shoulder", "Rear Deltoid", "Cable Rear Delt Fly", "3", "10", "10", "Position the pulleys on a dual cable machine to shoulder height, grasp the handles with opposite hands (right hand to left pulley and vice versa), step into a staggered stance, and pull the handles outwards and back, keeping arms straight, then return to the start."]
BentOverReverseCableFly = ["Shoulder", "Rear Deltoid", "Bent-Over Reverse Cable Fly", "3", "10", "10", "Stand centered between the cables of a dual cable machine set to the lowest position, bend at the hips, grab the handles with opposite hands, and with a slight bend in the elbows, pull the handles out and up to shoulder height, then slowly return."]
HalfKneelingHighCableRow = ["Shoulder", "Rear Deltoid", "Half-Kneeling High Cable Row", "3", "10", "8", "Kneel on one knee in front of a high pulley, hold the cable handle with the opposite hand, pull the handle towards your lower chest while keeping your back straight and core engaged, then slowly extend your arm back."]
FacePull = ["Shoulder", "Rear Deltoid", "Face Pull", "3", "30", "12", "Attach a rope to a high pulley cable machine, grasp the rope with both hands, pull the rope towards your face while separating your hands, elbows high, then slowly return the rope to the starting position."]

### Chest ###
InclineBarbellBenchPress = ["Chest", "Lower Chest", "Incline Barbell Bench Pushup", "3", "30", "12", "This exercise is one of the most effective ways to target your upper chest muscles. Set up an incline bench to about a 30-45 degree angle and perform the bench press as you normally would, focusing on keeping your elbows close to your body."]
InclineDumbbellFly = ["Chest", "Lower Chest", "Incline Dumbbell Fly", "3", "30", "12", "The incline dumbbell fly is an effective exercise for building strength and definition in the upper chest muscles. The incline bench position helps to emphasize the upper chest muscles by allowing for a greater stretch in the chest muscles during the exercise. To perform the exercise, you start by holding a dumbbell in each hand with your arms extended above your chest and your palms facing each other."]
DeclinePushup = ["Chest", "Lower Chest", "Decline Pushup", "3", "30", "12", "Elevating your feet on a bench or step during push-ups shifts more of the emphasis onto the upper chest muscles. Start with a lower bench and work your way up to a higher one as you get stronger."]
FlatBenchPress = ["Chest", "Middle Chest", "Flat Bench Press", "3", "30", "12", "The cornerstone chest exercise. Keep your feet flat and back arched slightly, lowering the bar to mid-chest before pressing up."]
HighCableCrossovers = ["Chest", "Lower Chest", "Higher Cable Crossovers", "3", "30", "12", "The high cable crossover is an excellent exercise for chest development, as it stretches the chest muscles and increases range of motion. The exercise works the lower, inner, and outer areas of the pecs, which helps achieve a well-rounded chest workout and build overall chest strength."]
InclinePushup = ["Chest", "Lower Chest", "Incline Pushup", "3", "30", "12", "Targeting the lower chest and triceps, grasp parallel bars, lean slightly forward, lower your body until your shoulders are just below your elbows, then push back up to the starting position."]
ChestDip = ["Chest", "Lower Chest", "Chest Dip", "3", "30", "12", "Focusing on the lower chest and shoulders, place your hands on an elevated surface like a bench, keep your body straight, lower your chest to the edge, and push back up to the start."]

### Biceps ###


CloseGripBarbellCurl = ["Biceps", "Long Head", "Close Grip Barbell Curl", "3", "40", "8", "Shoulder width barbell curls are the standard width, but when you use a narrow grip you will add slightly more emphasis to the long head (outer part) of the biceps. In regards to barbell curls, you can vary the placement of your hands to vary the emphasis of the exercise. "]
DumbbellBicepCurl = ["Biceps", "Long Head", "Close Grip Barbell Curl", "3", "20", "8", "Move in a slow and controlled manner. If you move too quickly, momentum will take over and your biceps will actually work a less when momentum takes over. One of the main compensations during this bicep exercise is arching the back to assist in lifting the weight. If your back moves, that is a sign that the weight is too heavy, so try a lighter weight or do less repetitions on the next set."]

EzBarPreacherCurl = ["Biceps", "Short Head", "Ez Bar Preacher Curl", "3", "40", "8", "The first benefit is that the EZ bar takes pressure off your wrists. Because the bar is curved, your wrist does not have to be completely turned up (supinated), and this takes some pressure off the wrist joint. The second benefit is that the preacher bench provides some added stability, so you will generally be able to lift a little more weight compared with standing. Also, the preacher bench helps to isolate the biceps, so you slightly more muscle work."]
ConcentrationCurl = ["Biceps", "Short Head", "Concentration Curl", "3", "25", "8", "Isolate the biceps for focused growth by sitting, spreading your legs, resting one arm against your inner thigh, and curling a dumbbell from knee level towards your chest, keeping your upper arm stationary."]


HammerCurl = ["Biceps", "Brachialis", "Hammer Curl", "3", "20", "8", "When you are in the neutral position, your hand is in the hand shake position. The biceps still works well in this position, but another forearm muscle (the brachioradialis) is in its best position. And when your palms are face down, like in a reverse barbell curl, your biceps is at its weakest position."]
CableRopeHammerCurl = ["Biceps", "Brachialis", "Cable Rope Hammer Curl", "3", "40", "8", "During hammer curls, it is important to make sure that you keep your thumbs pointing towards the ceiling throughout the entire movement. When your palm is in the “hand shake position” (thumbs up) during bicep exercises, the brachioradialis and brachialis are emphasized."]

# %%
df = pd.DataFrame(data = [DumbbellShoulderPress, DumbbellFrontRaise, ArnoldPress, LeverShoulderPress,
                         DumbbellLateralRaise, CableLateralRaise, 
                         CableRearDeltFly, BentOverReverseCableFly, HalfKneelingHighCableRow, FacePull,
                         InclineBarbellBenchPress, InclineDumbbellFly, DeclinePushup, FlatBenchPress, HighCableCrossovers, InclinePushup, ChestDip,
                         CloseGripBarbellCurl, DumbbellBicepCurl, EzBarPreacherCurl, ConcentrationCurl, HammerCurl, CableRopeHammerCurl])
df.columns = ["Muscle Group", "Target Muscle", "Workout Name", "Sets", "lbs", "Reps", "Description"]
df
# Out:
#    Muscle Group    Target Muscle                  Workout Name Sets lbs Reps  \
# 0      Shoulder    Front Deltoid       Dumbbell Shoulder Press    3  30   10
# 1      Shoulder    Front Deltoid          Dumbbell Front Raise    3  10   10
# 2      Shoulder    Front Deltoid                  Arnold Press    3  30    8
# 3      Shoulder    Front Deltoid          Lever Shoulder Press    3  70    8
# 4      Shoulder  Lateral Deltoid        Dumbbell Lateral Raise    3  10   10
# 5      Shoulder  Lateral Deltoid           Cable Lateral Raise    3  10   10
# 6      Shoulder     Rear Deltoid           Cable Rear Delt Fly    3  10   10
# 7      Shoulder     Rear Deltoid   Bent-Over Reverse Cable Fly    3  10   10
# 8      Shoulder     Rear Deltoid  Half-Kneeling High Cable Row    3  10    8
# 9      Shoulder     Rear Deltoid                     Face Pull    3  30   12
# 10        Chest      Lower Chest  Incline Barbell Bench Pushup    3  30   12
# ...

# %% [markdown]
# # Diet

# %%
# Defining Total Daily Energy Expenditure

Izzy_weight = 72.7 # kg
Izzy_height = 180 # cm
Izzy_age = 20 # years old
Izzy_PAL_active = 1.55
Izzy_PAL_inactive = 1.2
low_carb_diet = {"Carbs": 0.25, "Protein": 0.35, "Fats": 0.4}

Izzy_TTDE = Izzy_PAL_active * (10 * Izzy_weight + 6.25 * Izzy_height - 5 * Izzy_age + 5)
Izzy_TTDE_inactive = Izzy_PAL_inactive * (10 * Izzy_weight + 6.25 * Izzy_height - 5 * Izzy_age + 5)

print(f"Daily Required Calories for moderately active: {Izzy_TTDE:.1f} kcal")
print(f"Daily Required Calories for inactive: {Izzy_TTDE_inactive:.1f} kcal")
# Out:
# Daily Required Calories for moderately active: 2723.3 kcal
# Daily Required Calories for inactive: 2108.4 kcal

# %%
daily_nutrition_df = pd.DataFrame(data = [[round(i * low_carb_diet["Carbs"] / 4, 1) for i in [Izzy_TTDE, Izzy_TTDE_inactive]],
[round(i * low_carb_diet["Protein"] / 4, 1) for i in [Izzy_TTDE, Izzy_TTDE_inactive]],
[round(i * low_carb_diet["Fats"] / 9, 1) for i in [Izzy_TTDE, Izzy_TTDE_inactive]]], index = list(low_carb_diet.keys()))
daily_nutrition_df = daily_nutrition_df.T
daily_nutrition_df.index = ["Moderately active", "Inactive"]
daily_nutrition_df
# Out:
#                    Carbs  Protein   Fats
# Moderately active  170.2    238.3  121.0
# Inactive           131.8    184.5   93.7

# %%
school_life_df = pd.read_excel("Diet Planner.xlsx", sheet_name = "School Life")
school_life_df
# Out:
#                 Components             Servings  Calories  Carbohydrates (g)  \
# 0               Boiled Egg        1 large (50g)        68                0.6
# 1   Extra Virgin Olive Oil        1 tbsp (15ml)       119                0.0
# 2                  Edamame         1 cup (155g)       188               13.8
# 3              Black Beans         1 cup (172g)       227               40.8
# 4              Feta Cheese           1 oz (28g)        75                1.2
# 5                Guacamole        1/4 cup (60g)       100                5.0
# 6            Salad Lettuce          1 cup (36g)         5                0.9
# 7              Green Beans         1 cup (125g)        44                9.9
# 8           Sweet Potatoes   1 cup cubed (133g)       114               26.8
# 9           Chicken Thighs       1 thigh (109g)       209                0.0
# 10         Chicken Breasts      1 breast (174g)       284                0.0
# ...

# %% [markdown]
# ## School Meal (Cereal - Dining Hall - Greek Yogurt)

# %%
meals_df = pd.read_excel("Diet Planner.xlsx", sheet_name = "Meals")
# meals_df = meals_df.append(meals_df.loc[0], ignore_index=True) # Cereal for dinner
meals_df = meals_df.append(school_life_df.loc[9], ignore_index=True) # chicken thigh
meals_df = meals_df.append(school_life_df.loc[12], ignore_index=True) # salmon
meals_df = meals_df.append(school_life_df.loc[13], ignore_index=True) # beef (three servings of meat)
meals_df = meals_df.append(school_life_df.loc[18], ignore_index=True) # quinoa
meals_df = meals_df.append(school_life_df.loc[18], ignore_index=True) # quinoa
meals_df = meals_df.append(school_life_df.loc[24], ignore_index=True) # banana
meals_df = meals_df.append(school_life_df.loc[24], ignore_index=True) # banana
meals_df = meals_df.append(school_life_df.loc[21], ignore_index=True) # two yogurts for dinner
meals_df = meals_df.append(school_life_df.loc[21], ignore_index=True) # two yogurts for dinner
meals_df = meals_df.append(school_life_df.loc[1], ignore_index=True) # add some olive oil
meals_df = meals_df.append(school_life_df.loc[1], ignore_index=True) # add some olive oil

sums_row = meals_df.select_dtypes(include=['number']).sum()
sums_row.to_dict()
sums_row["Components"] = "Total"
sums_row["Servings"] = "-"
ttde_row = sums_row.copy()
ttde_row["Calories"] = round(Izzy_TTDE, 1)
ttde_row["Carbohydrates (g)"] = round(Izzy_TTDE * low_carb_diet["Carbs"] / 4, 1)
ttde_row["Protein (g)"] = round(Izzy_TTDE * low_carb_diet["Protein"] / 4, 1)
ttde_row["Fats (g)"] = round(Izzy_TTDE * low_carb_diet["Fats"] / 9, 1)
ttde_row["Fiber (g)"] = 35
ttde_row["Sodium (mg)"] = 0
ttde_row["Components"] = "Daily Limit"
meals_df = meals_df.append(sums_row, ignore_index=True)
meals_df = meals_df.append(ttde_row, ignore_index=True)
cal_diff = sums_row["Calories"] - ttde_row["Calories"]
print(f"""Total Daily Calories: {sums_row["Calories"]} kcal""")
if cal_diff > 0:
    print(f"""Calories Surplus of {cal_diff:.2f} kcal""")
else:
    print(f"""Calories Deficit of {-cal_diff:.2f} kcal""")
print(f"""Percent Carbohydrates: {(sums_row["Carbohydrates (g)"]*4/sums_row["Calories"])*100:.2f}%""")
print(f"""Percent Protein: {(sums_row["Protein (g)"]*4/sums_row["Calories"])*100:.2f}%""")
print(f"""Percent Fats: {(sums_row["Fats (g)"]*9/sums_row["Calories"])*100:.2f}%""")

meals_df
# Out:
# Total Daily Calories: 2679.0 kcal
# Calories Deficit of 44.30 kcal
# Percent Carbohydrates: 39.57%
# Percent Protein: 27.22%
# Percent Fats: 33.85%
#                 Components             Servings  Calories  Carbohydrates (g)  \
# 0                   Cereal               1 bowl     344.0               53.7
# 1           Bowl of Greens               1 bowl     283.0               28.5
# 2           Granola Yogurt                1 cup     309.0               38.0
# 3           Chicken Thighs       1 thigh (109g)     209.0                0.0
# 4             Baked Salmon          4 oz (113g)     230.0                0.0
# 5             Braised Beef           3 oz (85g)     212.0                0.0
# 6                   Quinoa  1 cup cooked (185g)     222.0               39.4
# 7                   Quinoa  1 cup cooked (185g)     222.0               39.4
# 8                  Bananas      1 medium (118g)     105.0               27.0
# ...

# %% [markdown]
# ## Yogurt Meal lol (Greek Yogurt - Dining Hall - Greek Yogurt)

# %%
meals_df = pd.read_excel("Diet Planner.xlsx", sheet_name = "Meals")
meals_df = meals_df.drop(meals_df.index[0])
meals_df = meals_df.append(school_life_df.loc[21], ignore_index=True) # two yogurts for breakfast
meals_df = meals_df.append(school_life_df.loc[21], ignore_index=True) # two yogurts for breakfast
meals_df = meals_df.append(school_life_df.loc[9], ignore_index=True) # chicken thigh
meals_df = meals_df.append(school_life_df.loc[12], ignore_index=True) # salmon
meals_df = meals_df.append(school_life_df.loc[13], ignore_index=True) # beef (three servings of meat)
meals_df = meals_df.append(school_life_df.loc[18], ignore_index=True) # quinoa
meals_df = meals_df.append(school_life_df.loc[18], ignore_index=True) # quinoa
meals_df = meals_df.append(school_life_df.loc[24], ignore_index=True) # banana
meals_df = meals_df.append(school_life_df.loc[24], ignore_index=True) # banana
meals_df = meals_df.append(school_life_df.loc[21], ignore_index=True) # two yogurts for dinner
meals_df = meals_df.append(school_life_df.loc[21], ignore_index=True) # two yogurts for dinner
meals_df = meals_df.append(school_life_df.loc[1], ignore_index=True) # add some olive oil
meals_df = meals_df.append(school_life_df.loc[1], ignore_index=True) # add some olive oil

sums_row = meals_df.select_dtypes(include=['number']).sum()
sums_row.to_dict()
sums_row["Components"] = "Total"
sums_row["Servings"] = "-"
ttde_row = sums_row.copy()
ttde_row["Calories"] = round(Izzy_TTDE, 1)
ttde_row["Carbohydrates (g)"] = round(Izzy_TTDE * low_carb_diet["Carbs"] / 4, 1)
ttde_row["Protein (g)"] = round(Izzy_TTDE * low_carb_diet["Protein"] / 4, 1)
ttde_row["Fats (g)"] = round(Izzy_TTDE * low_carb_diet["Fats"] / 9, 1)
ttde_row["Fiber (g)"] = 35
ttde_row["Sodium (mg)"] = 0
ttde_row["Components"] = "Daily Limit"
meals_df = meals_df.append(sums_row, ignore_index=True)
meals_df = meals_df.append(ttde_row, ignore_index=True)
cal_diff = sums_row["Calories"] - ttde_row["Calories"]
print(f"""Total Daily Calories: {sums_row["Calories"]} kcal""")
if cal_diff > 0:
    print(f"""Calories Surplus of {cal_diff:.2f} kcal""")
else:
    print(f"""Calories Deficit of {-cal_diff:.2f} kcal""")
print(f"""Percent Carbohydrates: {(sums_row["Carbohydrates (g)"]*4/sums_row["Calories"])*100:.2f}%""")
print(f"""Percent Protein: {(sums_row["Protein (g)"]*4/sums_row["Calories"])*100:.2f}%""")
print(f"""Percent Fats: {(sums_row["Fats (g)"]*9/sums_row["Calories"])*100:.2f}%""")

meals_df
# Out:
# Total Daily Calories: 2535.0 kcal
# Calories Deficit of 188.30 kcal
# Percent Carbohydrates: 35.23%
# Percent Protein: 32.21%
# Percent Fats: 32.63%
#                 Components             Servings  Calories  Carbohydrates (g)  \
# 0           Bowl of Greens               1 bowl     283.0               28.5
# 1           Granola Yogurt                1 cup     309.0               38.0
# 2             Greek Yogurt         1 cup (245g)     100.0                6.0
# 3             Greek Yogurt         1 cup (245g)     100.0                6.0
# 4           Chicken Thighs       1 thigh (109g)     209.0                0.0
# 5             Baked Salmon          4 oz (113g)     230.0                0.0
# 6             Braised Beef           3 oz (85g)     212.0                0.0
# 7                   Quinoa  1 cup cooked (185g)     222.0               39.4
# 8                   Quinoa  1 cup cooked (185g)     222.0               39.4
# ...
